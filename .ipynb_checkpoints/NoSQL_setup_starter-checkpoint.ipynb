# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --db uk_food --collection establishments --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that uk_food database was created
# List the available database names
database_names = mongo.list_database_names()

# Print database names
for db_name in database_names:
    print(db_name)
# Out:
# admin
# config
# local
# met
# uk_food

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
# List the collections in the "uk_food" database
collection_names = db.list_collection_names()

# Print
for collection_name in collection_names:
    print(collection_name)
# Out:
# establishments

# %%
# review a document in the establishments collection
collection = db['establishments']
document = collection.find_one()
pprint(document)
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6484d3b7113e7c5626d3dbf6'),
#  'geocode': {'latitude': {'$toDouble': '$geocode.latitude'},
#              'longitude': {'$toDouble': '$geocode.longitude'}},
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
document = {
    "BusinessName": "Penang Flavours",
    "BusinessType": "Restaurant/Cafe/Canteen",
    "BusinessTypeID": "",
    "AddressLine1": "Penang Flavours",
    "AddressLine2": "146A Plumstead Rd",
    "AddressLine3": "London",
    "AddressLine4": "",
    "PostCode": "SE18 7DY",
    "Phone": "",
    "LocalAuthorityCode": "511",
    "LocalAuthorityName": "Greenwich",
    "LocalAuthorityWebSite": "http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress": "health@royalgreenwich.gov.uk",
    "scores": {
        "Hygiene": "",
        "Structural": "",
        "ConfidenceInManagement": ""
    },
    "SchemeType": "FHRS",
    "geocode": {
        "longitude": "0.08384000",
        "latitude": "51.49014200"
    },
    "RightToReply": "",
    "Distance": 4623.9723280747176,
    "NewRatingPending": True
}

# %%
# Insert the new restaurant into the collection
insert_result = establishments.insert_one(document)

# %%
# Check that the new restaurant was inserted
print("Inserted document ID:", insert_result.inserted_id)
# Out:
# Inserted document ID: 6485ff17d1020c889ec393f9

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
# Define the query filter
query = {
    "BusinessType": "Restaurant/Cafe/Canteen"
}

# Define the projection
projection = {
    "_id": 0,  # Exclude the "_id" field
    "BusinessTypeID": 1,
    "BusinessType": 1
}

# Find the matching documents
results = establishments.find(query, projection)

# Print the results
for result in results:
    print(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
# Define the query filter
query = {
    "BusinessName": "Penang Flavours"
}    
# Define the update command to set the BusinessTypeID
update = {
    "$set": {
        "BusinessTypeID": "1"
    }
}
    
# Update the document
update_result = establishments.update_one(query, update)

# %%
# Confirm that the new restaurant was updated
# Print the number of documents
print("Matched documents:", update_result.matched_count)
print("Modified documents:", update_result.modified_count)
# Out:
# Matched documents: 1
# Modified documents: 0

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
# Define the query
query = {
    "LocalAuthorityName": "Dover"
}

# Count the documents
count = establishments.count_documents(query)

# Print
print("Number of documents with LocalAuthorityName as 'Dover':", count)
# Out:
# Number of documents with LocalAuthorityName as 'Dover': 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
# Define the query filter
query = {
    "LocalAuthorityName": "Dover"
}

# Delete the documents
delete_result = establishments.delete_many(query)

# Print the number of deleted documents
print("Number of documents deleted:", delete_result.deleted_count)
# Out:
# Number of documents deleted: 994

# %%
# Check if any remaining documents include Dover
# Define the query filter
query = {
    "LocalAuthorityName": "Dover"
}

# Count the remaining documents
count = establishments.count_documents(query)

if count > 0:
    print("There are remaining documents with 'Dover' in the 'LocalAuthorityName' field.")
else:
    print("There are no remaining documents with 'Dover' in the 'LocalAuthorityName' field.")
# Out:
# There are no remaining documents with 'Dover' in the 'LocalAuthorityName' field.

# %%
# Check that other documents remain with 'find_one'
# Find a single document
remaining_document = collection.find_one()

if remaining_document:
    print("There are remaining documents in the collection.")
else:
    print("There are no remaining documents in the collection.")
# Out:
# There are remaining documents in the collection.

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
# Define the query filter
query = {}

# Define the update operation
update = {
    "$set": {
        "geocode.longitude": {
            "$toDouble": "$geocode.longitude"
        },
        "geocode.latitude": {
            "$toDouble": "$geocode.latitude"
        }
    }
}

# Update the documents
update_result = establishments.update_many(query, update)

# Print the number of modified documents
print("Number of modified documents:", update_result.modified_count)
# Out:
# Number of modified documents: 38786

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
# Define the query filter
query = {
    "RatingValue": {"$type": "string"}  # Filter documents with RatingValue as a string
}

# Define the update operation
update = [
    {
        "$set": {
            "RatingValue": {
                "$cond": [
                    {"$in": ["$RatingValue", non_ratings]},
                    None,
                    {"$toInt": "$RatingValue"}
                ]
            }
        }
    }
]

# Update the documents
update_result = establishments.update_many(query, update)

# Print the number of modified documents
print("Number of modified documents:", update_result.modified_count)
# Out:
# Number of modified documents: 34694
